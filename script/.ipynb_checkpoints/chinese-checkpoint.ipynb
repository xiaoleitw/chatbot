# %%
import csv

def read_chinese():
    reader = csv.reader(open("../raw-data/chinese.txt", 'r', encoding='utf-8'), delimiter=" ")
    result = []
    for i in reader:
        result += i
        
    return result

# %%
read_chinese()
# Out:
# ['乙',
#  '十',
#  '丁',
#  '厂',
#  '七',
#  '卜',
#  '人',
#  '入',
#  '八',
#  '九',
#  '几',
#  '儿',
#  '了',
#  '力',
#  '乃',
#  '刀',
#  '又',
#  '于',
#  '干',
#  '亏',
#  '士',
#  '工',
#  '土',
#  '才',
#  '寸',
#  '下',
#  '大',
#  '丈',
#  '与',
#  '万',
#  '上',
#  '小',
#  '口',
#  '巾',
#  '山',
#  '千',
#  '乞',
#  '川',
#  '亿',
#  '个',
#  '勺',
#  '久',
#  '凡',
#  '及',
#  '夕',
#  '丸',
#  '么',
#  '广',
#  '亡',
#  '门',
#  '义',
#  '之',
#  '尸',
#  '弓',
#  '己',
#  '已',
#  '子',
#  '卫',
#  '也',
#  '女',
#  '飞',
#  '刃',
#  '习',
#  '叉',
#  '马',
#  '乡',
#  '丰',
#  '王',
#  '井',
#  '开',
#  '夫',
#  '天',
#  '无',
#  '元',
#  '专',
#  '云',
#  '扎',
#  '艺',
#  '木',
#  '五',
#  '支',
#  '厅',
#  '不',
#  '太',
#  '犬',
#  '区',
#  '历',
#  '尤',
#  '友',
#  '匹',
#  '车',
#  '巨',
#  '牙',
#  '屯',
#  '比',
#  '互',
#  '切',
#  '瓦',
#  '止',
#  '少',
#  '日',
#  '中',
#  '冈',
#  '贝',
#  '内',
#  '水',
#  '见',
#  '午',
#  '牛',
#  '手',
#  '毛',
#  '气',
#  '升',
#  '长',
#  '仁',
#  '什',
#  '片',
#  '仆',
#  '化',
#  '仇',
#  '币',
#  '仍',
#  '仅',
#  '斤',
#  '爪',
# ...
