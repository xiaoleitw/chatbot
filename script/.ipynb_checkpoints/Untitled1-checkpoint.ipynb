# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-a7c3cf678956> in <module>()
# ----> 1 import CRFPP
#       2 import sys
#       3
#       4 def parse_sentence(model, sentence):
#       5     which_model = "../train/" + model + "/model"
#
# ModuleNotFoundError: No module named 'CRFPP'
